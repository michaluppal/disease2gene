# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import pickle
import gzip
import glob
import os
import logging
from urllib.parse import urljoin
import concurrent.futures # For parallelization

# --- Configuration ---
logging.basicConfig(filename='fetch_papers_errors.log', level=logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s')

REQUEST_HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}
# This delay is applied *before* fetching the final full-text URL from a publisher/PMC site by each worker.
FETCH_DELAY_SECONDS = 2 # Slightly reduced, but still important for politeness.
MAX_WORKERS = 5 # Number of parallel threads. Adjust based on your network and CPU. Too many can still cause issues.

# --- Helper Functions ---

def fetch_url_content(url, retries=1, base_retry_delay=1, timeout=1):
    for attempt in range(retries):
        try:
            response = requests.get(url, headers=REQUEST_HEADERS, timeout=timeout, allow_redirects=True)
            response.raise_for_status()
            logging.info(f"Successfully fetched {url} with status {response.status_code}")
            return response
        except requests.exceptions.Timeout:
            logging.warning(f"Timeout on attempt {attempt + 1}/{retries} for {url}")
        except requests.exceptions.HTTPError as e:
            logging.warning(f"HTTP error {e.response.status_code} on attempt {attempt + 1}/{retries} for {url}")
            if e.response.status_code == 404: # Don't retry if not found
                break
        except requests.exceptions.RequestException as e:
            logging.warning(f"Request error on attempt {attempt + 1}/{retries} for {url}: {e}")

        if attempt < retries - 1:
            # Simple incremental backoff for retries
            current_delay = base_retry_delay * (attempt + 1)
            logging.info(f"Waiting {current_delay} seconds before retry for {url}...")
            time.sleep(current_delay)
    logging.error(f"Failed to fetch {url} after {retries} retries.")
    return None

def get_full_text_data(pmid: str):
    pubmed_base_url = 'https://pubmed.ncbi.nlm.nih.gov/'
    pmid_url = f'{pubmed_base_url}{pmid}/'
    # Logging the start of processing for a PMID is now better done before submitting to the pool
    # logging.info(f"Processing PMID: {pmid} - URL: {pmid_url}")

    pubmed_response = fetch_url_content(pmid_url)
    if not pubmed_response or not pubmed_response.text:
        logging.error(f"Failed to fetch PubMed page for PMID {pmid}")
        return {"pmid": pmid, "type": "error", "content": "Failed to fetch PubMed page", "final_url": pmid_url}

    soup = BeautifulSoup(pubmed_response.text, 'html.parser')
    full_text_div = soup.find('div', class_='full-text-links-list')
    links_found = []

    if not full_text_div:
        logging.debug(f"No 'full-text-links-list' div found for PMID {pmid}. Checking for single prominent link.")
        single_link = soup.find('a', class_='link-item dialog-focus')
        if single_link and single_link.get('href'):
             links_found = [single_link]
             logging.debug(f"Found single prominent full text link for PMID {pmid}")
        else:
            logging.warning(f"No full text links (list or single) found for PMID {pmid}")
            return {"pmid": pmid, "type": "error", "content": "No full-text links found on PubMed page", "final_url": pmid_url}
    else:
        links_found = full_text_div.find_all('a', class_='link-item')

    if not links_found: # Should be caught above, but as a safeguard
        logging.warning(f"No links extracted from full_text_div or single link for PMID {pmid}")
        return {"pmid": pmid, "type": "error", "content": "No links extracted from full_text_div", "final_url": pmid_url}

    full_text_target_url = None
    is_pmc_link = False

    for link in links_found:
        href = link.get('href')
        if not href:
            continue

        current_link_url = urljoin(pmid_url, href)
        link_text_lower = link.get_text(strip=True).lower()
        href_lower = href.lower()

        if "ncbi.nlm.nih.gov/pmc" in current_link_url or "europepmc.org" in current_link_url or \
           "pmc" in link.get('data-ga-action', '').lower() or "pmc" in link_text_lower or "pmc" in href_lower:
            full_text_target_url = current_link_url
            is_pmc_link = True
            logging.info(f"Prioritized PMC link for PMID {pmid}: {full_text_target_url}")
            break

    if not full_text_target_url and links_found:
        first_link_href = links_found[0].get('href')
        if first_link_href:
            full_text_target_url = urljoin(pmid_url, first_link_href)
            logging.info(f"Using first available link (non-PMC priority) for PMID {pmid}: {full_text_target_url}")

    if not full_text_target_url:
        logging.error(f"No valid full text URL could be resolved for PMID {pmid}")
        return {"pmid": pmid, "type": "error", "content": "No valid full-text URL resolved", "final_url": pmid_url}

    logging.info(f"PMID {pmid}: Attempting to fetch full content from: {full_text_target_url}")
    time.sleep(FETCH_DELAY_SECONDS) # Crucial delay before hitting external sites

    article_response = fetch_url_content(full_text_target_url)
    if article_response and article_response.text:
        content_type_header = article_response.headers.get('Content-Type', '').lower()
        determined_type = 'html'

        if 'xml' in content_type_header:
            determined_type = 'xml'
        elif is_pmc_link and "PMC" in full_text_target_url and not full_text_target_url.endswith(('.pdf', '.epub')):
            if article_response.text.strip().startswith('<') and \
               ("<article" in article_response.text[:1000] or "<front>" in article_response.text[:1000]):
                determined_type = 'xml'
                logging.info(f"Detected XML-like content from PMC for PMID {pmid} by inspection.")

        logging.info(f"Successfully retrieved content for PMID {pmid} from {full_text_target_url}. Type: {determined_type}, Length: {len(article_response.text)}")
        return {
            "pmid": pmid,
            "type": determined_type,
            "content": article_response.text,
            "final_url": full_text_target_url
        }
    else:
        logging.error(f"Failed to fetch full content for PMID {pmid} from {full_text_target_url}")
        return {"pmid": pmid, "type": "error", "content": f"Failed to fetch from {full_text_target_url}", "final_url": full_text_target_url}

# --- Main Script ---
def main():
    csv_files = glob.glob('pubmed_genetic_results_*.csv')
    if not csv_files:
        logging.error("No pubmed_genetic_results_*.csv files found in the current directory.")
        print("Error: No pubmed_genetic_results_*.csv files found.")
        return
    latest_csv_file = max(csv_files, key=os.path.getctime)
    logging.info(f"Using input CSV file: {latest_csv_file}")
    print(f"Using input CSV file: {latest_csv_file}")

    try:
        df = pd.read_csv(latest_csv_file)
    except FileNotFoundError:
        logging.error(f"CSV file {latest_csv_file} not found.")
        print(f"Error: {latest_csv_file} not found.")
        return
    except Exception as e:
        logging.error(f"Error reading CSV {latest_csv_file}: {e}")
        print(f"Error reading CSV {latest_csv_file}: {e}")
        return

    if 'PMID' not in df.columns:
        logging.error("CSV file must contain a 'PMID' column.")
        print("Error: CSV file must contain a 'PMID' column.")
        return

    all_pmids_from_csv = df['PMID'].astype(str).unique().tolist()
    logging.info(f"Found {len(all_pmids_from_csv)} unique PMIDs to process from {latest_csv_file}.")
    print(f"Found {len(all_pmids_from_csv)} unique PMIDs to process.")

    content_dict = {}
    output_filename = "content_dict.pkl.gz"

    if os.path.exists(output_filename):
        try:
            with gzip.open(output_filename, 'rb') as f_load:
                content_dict = pickle.load(f_load)
            logging.info(f"Loaded {len(content_dict)} existing entries from {output_filename}")
            print(f"Loaded {len(content_dict)} existing entries from {output_filename}")
        except Exception as e:
            logging.warning(f"Could not load existing {output_filename}: {e}. Starting fresh.")
            content_dict = {}

    pmids_to_fetch = [pmid for pmid in all_pmids_from_csv if pmid not in content_dict]
    if not pmids_to_fetch:
        print("All PMIDs from the CSV have already been processed. Nothing new to fetch.")
        logging.info("All PMIDs from the CSV have already been processed.")
        return

    logging.info(f"Attempting to fetch content for {len(pmids_to_fetch)} new PMIDs.")
    print(f"Attempting to fetch content for {len(pmids_to_fetch)} new PMIDs.")

    # Using ThreadPoolExecutor for parallel fetching
    # The main rate limiting per external site is handled by FETCH_DELAY_SECONDS within get_full_text_data
    # MAX_WORKERS limits simultaneous calls to PubMed for initial pages.
    results_from_fetch = []
    with concurrent.futures.ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        future_to_pmid = {executor.submit(get_full_text_data, pmid): pmid for pmid in pmids_to_fetch}

        for future in tqdm(concurrent.futures.as_completed(future_to_pmid), total=len(pmids_to_fetch), desc="Fetching paper content", unit="PMID"):
            pmid = future_to_pmid[future]
            try:
                data = future.result()
                if data:
                    results_from_fetch.append(data)
            except Exception as exc:
                logging.error(f"PMID {pmid} generated an exception during parallel execution: {exc}")
                results_from_fetch.append({"pmid": pmid, "type": "error", "content": f"Exception: {exc}", "final_url": None})

    newly_processed_count = 0
    for result_item in results_from_fetch:
        pmid = result_item["pmid"]
        # Ensure we don't overwrite potentially valid older data with a new error if it was somehow re-queued
        if pmid not in content_dict or content_dict[pmid].get("type") == "error":
             content_dict[pmid] = {
                "type": result_item["type"],
                "content": result_item["content"],
                "final_url": result_item["final_url"]
            }
        if result_item["type"] != "error":
            newly_processed_count +=1


    if results_from_fetch: # Save if any new processing was attempted
        try:
            with gzip.open(output_filename, 'wb') as f_save:
                pickle.dump(content_dict, f_save)
            logging.info(f"Saved results: {newly_processed_count} new PMIDs successfully processed in this run.")
            logging.info(f"Total entries in {output_filename}: {len(content_dict)}")
            print(f"\nSaved results. Total entries in {output_filename}: {len(content_dict)}")
        except Exception as e_save:
            logging.error(f"Error saving final results to {output_filename}: {e_save}")
            print(f"\nError saving final results: {e_save}")
    else:
        print("No new PMIDs were processed in this run.")


    logging.info(f"Finished processing. Total new PMIDs successfully processed in this run: {newly_processed_count}")
    print(f"\nFetching complete. Total successfully processed new PMIDs: {newly_processed_count}. Total entries in {output_filename}: {len(content_dict)}")

if __name__ == "__main__":
    main()
# Out:
# Using input CSV file: pubmed_genetic_results_68a3f3d2.csv
# Found 923 unique PMIDs to process.
# Attempting to fetch content for 923 new PMIDs.
# Fetching paper content:   0%|          | 0/923 [00:00<?, ?PMID/s]
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.ahajournals.org/doi/10.1161/CIRCULATIONAHA.109.191959?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.ahajournals.org/doi/10.1161/CIRCULATIONAHA.109.191959?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 19246689 from https://www.ahajournals.org/doi/10.1161/CIRCULATIONAHA.109.191959?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:Timeout on attempt 1/1 for https://doi.org/10.1038/ng.981
# ERROR:root:Failed to fetch https://doi.org/10.1038/ng.981 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 22081228 from https://doi.org/10.1038/ng.981
# WARNING:root:Timeout on attempt 1/1 for https://ashpublications.org/blood/article-lookup/doi/10.1182/blood-2003-07-2531
# ERROR:root:Failed to fetch https://ashpublications.org/blood/article-lookup/doi/10.1182/blood-2003-07-2531 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 14630794 from https://ashpublications.org/blood/article-lookup/doi/10.1182/blood-2003-07-2531
# WARNING:root:Timeout on attempt 1/1 for https://doi.org/10.1038/ng.2220
# ERROR:root:Failed to fetch https://doi.org/10.1038/ng.2220 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 22446962 from https://doi.org/10.1038/ng.2220
# WARNING:root:Timeout on attempt 1/1 for https://jamanetwork.com/journals/jamadermatology/fullarticle/10.1001/archderm.142.12.1591
# ERROR:root:Failed to fetch https://jamanetwork.com/journals/jamadermatology/fullarticle/10.1001/archderm.142.12.1591 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 17178985 from https://jamanetwork.com/journals/jamadermatology/fullarticle/10.1001/archderm.142.12.1591
# WARNING:root:HTTP error 403 on attempt 1/1 for https://onlinelibrary.wiley.com/resolve/openurl?genre=article&sid=nlm:pubmed&issn=0803-5253&date=2003&volume=92&issue=6&spage=694
# ERROR:root:Failed to fetch https://onlinelibrary.wiley.com/resolve/openurl?genre=article&sid=nlm:pubmed&issn=0803-5253&date=2003&volume=92&issue=6&spage=694 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 12856980 from https://onlinelibrary.wiley.com/resolve/openurl?genre=article&sid=nlm:pubmed&issn=0803-5253&date=2003&volume=92&issue=6&spage=694
# WARNING:root:HTTP error 403 on attempt 1/1 for https://onlinelibrary.wiley.com/doi/10.1002/art.22644
# ERROR:root:Failed to fetch https://onlinelibrary.wiley.com/doi/10.1002/art.22644 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 17530721 from https://onlinelibrary.wiley.com/doi/10.1002/art.22644
# WARNING:root:No full text links (list or single) found for PMID 7594509
# WARNING:root:Timeout on attempt 1/1 for https://jamanetwork.com/journals/jamadermatology/fullarticle/10.1001/archderm.142.9.1157
# ERROR:root:Failed to fetch https://jamanetwork.com/journals/jamadermatology/fullarticle/10.1001/archderm.142.9.1157 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 16983003 from https://jamanetwork.com/journals/jamadermatology/fullarticle/10.1001/archderm.142.9.1157
# WARNING:root:Timeout on attempt 1/1 for https://journals.aai.org/jimmunol/article-lookup/doi/10.4049/jimmunol.1600388
# ERROR:root:Failed to fetch https://journals.aai.org/jimmunol/article-lookup/doi/10.4049/jimmunol.1600388 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 27694492 from https://journals.aai.org/jimmunol/article-lookup/doi/10.4049/jimmunol.1600388
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1111/1756-185X.13218
# ERROR:root:Failed to fetch https://doi.org/10.1111/1756-185X.13218 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 29152908 from https://doi.org/10.1111/1756-185X.13218
# WARNING:root:Timeout on attempt 1/1 for https://doi.org/10.1038/tpj.2011.45
# ERROR:root:Failed to fetch https://doi.org/10.1038/tpj.2011.45 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 21987091 from https://doi.org/10.1038/tpj.2011.45
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/36538032/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/36538032/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 36538032
# WARNING:root:Timeout on attempt 1/1 for https://heart.bmj.com/lookup/pmidlookup?view=long&pmid=18697808
# ERROR:root:Failed to fetch https://heart.bmj.com/lookup/pmidlookup?view=long&pmid=18697808 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 18697808 from https://heart.bmj.com/lookup/pmidlookup?view=long&pmid=18697808
# WARNING:root:Timeout on attempt 1/1 for https://journals.aai.org/jimmunol/article-lookup/doi/10.4049/jimmunol.174.9.5837
# ERROR:root:Failed to fetch https://journals.aai.org/jimmunol/article-lookup/doi/10.4049/jimmunol.174.9.5837 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 15843588 from https://journals.aai.org/jimmunol/article-lookup/doi/10.4049/jimmunol.174.9.5837
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1111/1756-185X.13211
# ERROR:root:Failed to fetch https://doi.org/10.1111/1756-185X.13211 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 29115029 from https://doi.org/10.1111/1756-185X.13211
# WARNING:root:No full text links (list or single) found for PMID 21160486
# WARNING:root:HTTP error 403 on attempt 1/1 for https://onlinelibrary.wiley.com/doi/10.1002/1529-0131(200109)44:9<2211::aid-art375>3.0.co;2-a
# ERROR:root:Failed to fetch https://onlinelibrary.wiley.com/doi/10.1002/1529-0131(200109)44:9<2211::aid-art375>3.0.co;2-a after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 11592387 from https://onlinelibrary.wiley.com/doi/10.1002/1529-0131(200109)44:9<2211::aid-art375>3.0.co;2-a
# WARNING:root:HTTP error 403 on attempt 1/1 for https://onlinelibrary.wiley.com/resolve/openurl?genre=article&sid=nlm:pubmed&issn=0009-9163&date=2003&volume=63&issue=6&spage=490
# ERROR:root:Failed to fetch https://onlinelibrary.wiley.com/resolve/openurl?genre=article&sid=nlm:pubmed&issn=0009-9163&date=2003&volume=63&issue=6&spage=490 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 12786756 from https://onlinelibrary.wiley.com/resolve/openurl?genre=article&sid=nlm:pubmed&issn=0009-9163&date=2003&volume=63&issue=6&spage=490
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1111/jpc.12172
# ERROR:root:Failed to fetch https://doi.org/10.1111/jpc.12172 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 23560706 from https://doi.org/10.1111/jpc.12172
# WARNING:root:No full text links (list or single) found for PMID 10966868
# WARNING:root:HTTP error 403 on attempt 1/1 for https://onlinelibrary.wiley.com/doi/10.1111/j.1365-2958.2005.04862.x
# ERROR:root:Failed to fetch https://onlinelibrary.wiley.com/doi/10.1111/j.1365-2958.2005.04862.x after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 16238626 from https://onlinelibrary.wiley.com/doi/10.1111/j.1365-2958.2005.04862.x
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1002/art.38976
# ERROR:root:Failed to fetch https://doi.org/10.1002/art.38976 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 25470559 from https://doi.org/10.1002/art.38976
# WARNING:root:Timeout on attempt 1/1 for https://academic.oup.com/rheumatology/article-lookup/doi/10.1093/rheumatology/kel399
# ERROR:root:Failed to fetch https://academic.oup.com/rheumatology/article-lookup/doi/10.1093/rheumatology/kel399 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 17178739 from https://academic.oup.com/rheumatology/article-lookup/doi/10.1093/rheumatology/kel399
# WARNING:root:HTTP error 403 on attempt 1/1 for https://onlinelibrary.wiley.com/doi/10.1002/art.24261
# ERROR:root:Failed to fetch https://onlinelibrary.wiley.com/doi/10.1002/art.24261 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 19180512 from https://onlinelibrary.wiley.com/doi/10.1002/art.24261
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1002/art.40784
# ERROR:root:Failed to fetch https://doi.org/10.1002/art.40784 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 30447136 from https://doi.org/10.1002/art.40784
# WARNING:root:No full text links (list or single) found for PMID 9195529
# WARNING:root:HTTP error 403 on attempt 1/1 for https://onlinelibrary.wiley.com/doi/10.1002/art.21811
# ERROR:root:Failed to fetch https://onlinelibrary.wiley.com/doi/10.1002/art.21811 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 16645995 from https://onlinelibrary.wiley.com/doi/10.1002/art.21811
# ERROR:root:Failed to fetch full content for PMID 20412712 from http://www.clinexprheumatol.org/pubmed/find-pii.asp?pii=20412712
# WARNING:root:Timeout on attempt 1/1 for https://academic.oup.com/jid/article-lookup/doi/10.1086/345878
# ERROR:root:Failed to fetch https://academic.oup.com/jid/article-lookup/doi/10.1086/345878 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 12552460 from https://academic.oup.com/jid/article-lookup/doi/10.1086/345878
# WARNING:root:Timeout on attempt 1/1 for https://jmg.bmj.com/lookup/pmidlookup?view=long&pmid=21571869
# ERROR:root:Failed to fetch https://jmg.bmj.com/lookup/pmidlookup?view=long&pmid=21571869 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 21571869 from https://jmg.bmj.com/lookup/pmidlookup?view=long&pmid=21571869
# WARNING:root:HTTP error 403 on attempt 1/1 for https://onlinelibrary.wiley.com/doi/10.1002/art.21529
# ERROR:root:Failed to fetch https://onlinelibrary.wiley.com/doi/10.1002/art.21529 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 16385529 from https://onlinelibrary.wiley.com/doi/10.1002/art.21529
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/34381049/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/34381049/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 34381049
# WARNING:root:No full text links (list or single) found for PMID 10899738
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.ahajournals.org/doi/10.1161/CIRCGENETICS.116.001533?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.ahajournals.org/doi/10.1161/CIRCGENETICS.116.001533?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 27879314 from https://www.ahajournals.org/doi/10.1161/CIRCGENETICS.116.001533?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1002/ajmg.a.31148
# ERROR:root:Failed to fetch https://doi.org/10.1002/ajmg.a.31148 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 16532456 from https://doi.org/10.1002/ajmg.a.31148
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1002/jmv.10388
# ERROR:root:Failed to fetch https://doi.org/10.1002/jmv.10388 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 12696115 from https://doi.org/10.1002/jmv.10388
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.tandfonline.com/doi/10.1080/03009740802144143?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.tandfonline.com/doi/10.1080/03009740802144143?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 18720262 from https://www.tandfonline.com/doi/10.1080/03009740802144143?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:Timeout on attempt 1/1 for https://academic.oup.com/hmg/article-lookup/doi/10.1093/hmg/ddp586
# ERROR:root:Failed to fetch https://academic.oup.com/hmg/article-lookup/doi/10.1093/hmg/ddp586 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 20045869 from https://academic.oup.com/hmg/article-lookup/doi/10.1093/hmg/ddp586
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/28061462/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/28061462/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 28061462
# WARNING:root:No full text links (list or single) found for PMID 19158812
# WARNING:root:Timeout on attempt 1/1 for https://academic.oup.com/cid/article-lookup/doi/10.1086/432578
# ERROR:root:Failed to fetch https://academic.oup.com/cid/article-lookup/doi/10.1086/432578 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 16080076 from https://academic.oup.com/cid/article-lookup/doi/10.1086/432578
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/26434682/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/26434682/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 26434682
# WARNING:root:No full text links (list or single) found for PMID 28855716
# WARNING:root:Timeout on attempt 1/1 for https://doi.org/10.1159/000492354
# ERROR:root:Failed to fetch https://doi.org/10.1159/000492354 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 30078021 from https://doi.org/10.1159/000492354
# WARNING:root:No full text links (list or single) found for PMID 23677057
# WARNING:root:Timeout on attempt 1/1 for https://doi.org/10.1203/PDR.0b013e31815ef224
# ERROR:root:Failed to fetch https://doi.org/10.1203/PDR.0b013e31815ef224 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 18091353 from https://doi.org/10.1203/PDR.0b013e31815ef224
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.ahajournals.org/doi/10.1161/ATVBAHA.114.304846?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.ahajournals.org/doi/10.1161/ATVBAHA.114.304846?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 25838430 from https://www.ahajournals.org/doi/10.1161/ATVBAHA.114.304846?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:Timeout on attempt 1/1 for https://doi.org/10.1097/BOR.0b013e32832c49f2
# ERROR:root:Failed to fetch https://doi.org/10.1097/BOR.0b013e32832c49f2 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 19412104 from https://doi.org/10.1097/BOR.0b013e32832c49f2
# WARNING:root:No full text links (list or single) found for PMID 22011813
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1111/j.1442-200X.2012.03683.x
# ERROR:root:Failed to fetch https://doi.org/10.1111/j.1442-200X.2012.03683.x after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 22672194 from https://doi.org/10.1111/j.1442-200X.2012.03683.x
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1111/j.1399-0004.2010.01432.x
# ERROR:root:Failed to fetch https://doi.org/10.1111/j.1399-0004.2010.01432.x after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 20412081 from https://doi.org/10.1111/j.1399-0004.2010.01432.x
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1111/trf.13090
# ERROR:root:Failed to fetch https://doi.org/10.1111/trf.13090 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 26174898 from https://doi.org/10.1111/trf.13090
# WARNING:root:HTTP error 403 on attempt 1/1 for https://onlinelibrary.wiley.com/resolve/openurl?genre=article&sid=nlm:pubmed&issn=1328-8067&date=1999&volume=41&issue=4&spage=341
# ERROR:root:Failed to fetch https://onlinelibrary.wiley.com/resolve/openurl?genre=article&sid=nlm:pubmed&issn=1328-8067&date=1999&volume=41&issue=4&spage=341 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 10453180 from https://onlinelibrary.wiley.com/resolve/openurl?genre=article&sid=nlm:pubmed&issn=1328-8067&date=1999&volume=41&issue=4&spage=341
# WARNING:root:HTTP error 403 on attempt 1/1 for https://journals.sagepub.com/doi/10.1177/1470320311434240?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://journals.sagepub.com/doi/10.1177/1470320311434240?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 22277255 from https://journals.sagepub.com/doi/10.1177/1470320311434240?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1111/j.1744-313X.2010.00943.x
# ERROR:root:Failed to fetch https://doi.org/10.1111/j.1744-313X.2010.00943.x after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 20618519 from https://doi.org/10.1111/j.1744-313X.2010.00943.x
# WARNING:root:Timeout on attempt 1/1 for https://doi.org/10.1038/pr.2016.93
# ERROR:root:Failed to fetch https://doi.org/10.1038/pr.2016.93 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 27089500 from https://doi.org/10.1038/pr.2016.93
# WARNING:root:Timeout on attempt 1/1 for http://jgv.microbiologyresearch.org/pubmed/content/journal/jgv/10.1099/0022-1317-73-6-1581
# ERROR:root:Failed to fetch http://jgv.microbiologyresearch.org/pubmed/content/journal/jgv/10.1099/0022-1317-73-6-1581 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 1607874 from http://jgv.microbiologyresearch.org/pubmed/content/journal/jgv/10.1099/0022-1317-73-6-1581
# WARNING:root:HTTP error 403 on attempt 1/1 for https://onlinelibrary.wiley.com/doi/10.1002/art.33316
# ERROR:root:Failed to fetch https://onlinelibrary.wiley.com/doi/10.1002/art.33316 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 21905000 from https://onlinelibrary.wiley.com/doi/10.1002/art.33316
# WARNING:root:HTTP error 403 on attempt 1/1 for https://onlinelibrary.wiley.com/doi/10.1002/eji.201242398
# ERROR:root:Failed to fetch https://onlinelibrary.wiley.com/doi/10.1002/eji.201242398 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 22585560 from https://onlinelibrary.wiley.com/doi/10.1002/eji.201242398
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/26946987/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/26946987/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 26946987
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/35410860/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/35410860/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 35410860
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/36829193/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/36829193/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 36829193
# WARNING:root:No full text links (list or single) found for PMID 1491403
# WARNING:root:HTTP error 403 on attempt 1/1 for https://onlinelibrary.wiley.com/resolve/openurl?genre=article&sid=nlm:pubmed&issn=0385-5600&date=2005&volume=49&issue=2&spage=181
# ERROR:root:Failed to fetch https://onlinelibrary.wiley.com/resolve/openurl?genre=article&sid=nlm:pubmed&issn=0385-5600&date=2005&volume=49&issue=2&spage=181 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 15722603 from https://onlinelibrary.wiley.com/resolve/openurl?genre=article&sid=nlm:pubmed&issn=0385-5600&date=2005&volume=49&issue=2&spage=181
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/19508940/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/19508940/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 19508940
# WARNING:root:Timeout on attempt 1/1 for http://www.jrheum.org/lookup/pmidlookup?view=long&pmid=18484687
# ERROR:root:Failed to fetch http://www.jrheum.org/lookup/pmidlookup?view=long&pmid=18484687 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 18484687 from http://www.jrheum.org/lookup/pmidlookup?view=long&pmid=18484687
# WARNING:root:Timeout on attempt 1/1 for https://publications.aap.org/pediatrics/article-lookup/doi/10.1542/peds.114.1.e124
# ERROR:root:Failed to fetch https://publications.aap.org/pediatrics/article-lookup/doi/10.1542/peds.114.1.e124 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 15231984 from https://publications.aap.org/pediatrics/article-lookup/doi/10.1542/peds.114.1.e124
# WARNING:root:Timeout on attempt 1/1 for https://www.yiigle.com/LinkIn.do?linkin_type=pubmed&issn=0578-1310&year=2003&vol=41&issue=8&fpage=598
# ERROR:root:Failed to fetch https://www.yiigle.com/LinkIn.do?linkin_type=pubmed&issn=0578-1310&year=2003&vol=41&issue=8&fpage=598 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 14744383 from https://www.yiigle.com/LinkIn.do?linkin_type=pubmed&issn=0578-1310&year=2003&vol=41&issue=8&fpage=598
# WARNING:root:HTTP error 403 on attempt 1/1 for https://onlinelibrary.wiley.com/resolve/openurl?genre=article&sid=nlm:pubmed&issn=0001-2815&date=1992&volume=39&issue=2&spage=99
# ERROR:root:Failed to fetch https://onlinelibrary.wiley.com/resolve/openurl?genre=article&sid=nlm:pubmed&issn=0001-2815&date=1992&volume=39&issue=2&spage=99 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 1574805 from https://onlinelibrary.wiley.com/resolve/openurl?genre=article&sid=nlm:pubmed&issn=0001-2815&date=1992&volume=39&issue=2&spage=99
# WARNING:root:HTTP error 403 on attempt 1/1 for https://onlinelibrary.wiley.com/resolve/openurl?genre=article&sid=nlm:pubmed&issn=1328-8067&date=2003&volume=45&issue=2&spage=130
# ERROR:root:Failed to fetch https://onlinelibrary.wiley.com/resolve/openurl?genre=article&sid=nlm:pubmed&issn=1328-8067&date=2003&volume=45&issue=2&spage=130 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 12709136 from https://onlinelibrary.wiley.com/resolve/openurl?genre=article&sid=nlm:pubmed&issn=1328-8067&date=2003&volume=45&issue=2&spage=130
# WARNING:root:No full text links (list or single) found for PMID 25876998
# WARNING:root:Timeout on attempt 1/1 for https://academic.oup.com/rheumatology/article-lookup/doi/10.1093/rheumatology/key356
# ERROR:root:Failed to fetch https://academic.oup.com/rheumatology/article-lookup/doi/10.1093/rheumatology/key356 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 30535242 from https://academic.oup.com/rheumatology/article-lookup/doi/10.1093/rheumatology/key356
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/22498790/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/22498790/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 22498790
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/24294539/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/24294539/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 24294539
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/32956895/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/32956895/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 32956895
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/20202153/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/20202153/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 20202153
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/19468750/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/19468750/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 19468750
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/17874221/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/17874221/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 17874221
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/12783130/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/12783130/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 12783130
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/10881578/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/10881578/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 10881578
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/30968643/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/30968643/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 30968643
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/26833052/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/26833052/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 26833052
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/26769434/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/26769434/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 26769434
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/24773462/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/24773462/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 24773462
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/19543506/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/19543506/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 19543506
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/18481160/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/18481160/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 18481160
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/37523172/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/37523172/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 37523172
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/34625423/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/34625423/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 34625423
# WARNING:root:No full text links (list or single) found for PMID 15083896
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/27270653/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/27270653/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 27270653
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1111/pde.12905
# ERROR:root:Failed to fetch https://doi.org/10.1111/pde.12905 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 27435956 from https://doi.org/10.1111/pde.12905
# WARNING:root:HTTP error 404 on attempt 1/1 for http://www.elsevier.es/en/linksolver/ft/ivp/0025-7753/113/366
# ERROR:root:Failed to fetch http://www.elsevier.es/en/linksolver/ft/ivp/0025-7753/113/366 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 10562938 from http://www.elsevier.es/en/linksolver/ft/ivp/0025-7753/113/366
# WARNING:root:No full text links (list or single) found for PMID 9833707
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/28505365/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/28505365/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 28505365
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/37745025/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/37745025/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 37745025
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1111/j.1744-313X.2010.00952.x
# ERROR:root:Failed to fetch https://doi.org/10.1111/j.1744-313X.2010.00952.x after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 20618517 from https://doi.org/10.1111/j.1744-313X.2010.00952.x
# WARNING:root:Timeout on attempt 1/1 for http://www.psychiatrist.com/pcc/long-covid-children-adolescents
# ERROR:root:Failed to fetch http://www.psychiatrist.com/pcc/long-covid-children-adolescents after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 35486940 from http://www.psychiatrist.com/pcc/long-covid-children-adolescents
# ERROR:root:Failed to fetch full content for PMID 21906434 from http://www.clinexprheumatol.org/pubmed/find-pii.asp?pii=21906434
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1111/1756-185X.12911
# ERROR:root:Failed to fetch https://doi.org/10.1111/1756-185X.12911 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 27455075 from https://doi.org/10.1111/1756-185X.12911
# WARNING:root:Timeout on attempt 1/1 for https://dx.doi.org/10.1007/s00246-008-9341-x
# ERROR:root:Failed to fetch https://dx.doi.org/10.1007/s00246-008-9341-x after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 19048177 from https://dx.doi.org/10.1007/s00246-008-9341-x
# WARNING:root:No full text links (list or single) found for PMID 8755448
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.liebertpub.com/doi/10.1089/gtmb.2011.0001?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.liebertpub.com/doi/10.1089/gtmb.2011.0001?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 21815799 from https://www.liebertpub.com/doi/10.1089/gtmb.2011.0001?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.tandfonline.com/doi/10.1080/15513815.2019.1707917?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.tandfonline.com/doi/10.1080/15513815.2019.1707917?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 31884867 from https://www.tandfonline.com/doi/10.1080/15513815.2019.1707917?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:Timeout on attempt 1/1 for https://academic.oup.com/femsle/article-lookup/doi/10.1093/femsle/fny025
# ERROR:root:Failed to fetch https://academic.oup.com/femsle/article-lookup/doi/10.1093/femsle/fny025 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 29390083 from https://academic.oup.com/femsle/article-lookup/doi/10.1093/femsle/fny025
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.tandfonline.com/doi/10.3109/08820139.2016.1157812?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.tandfonline.com/doi/10.3109/08820139.2016.1157812?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 27105348 from https://www.tandfonline.com/doi/10.3109/08820139.2016.1157812?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch full content for PMID 27310036 from http://www.clinexprheumatol.org/pubmed/find-pii.asp?pii=27310036
# WARNING:root:Timeout on attempt 1/1 for https://www.cambridge.org/core/product/identifier/S1047951114000626/type/journal_article
# ERROR:root:Failed to fetch https://www.cambridge.org/core/product/identifier/S1047951114000626/type/journal_article after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 24775607 from https://www.cambridge.org/core/product/identifier/S1047951114000626/type/journal_article
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.tandfonline.com/doi/10.1517/14622416.1.4.417?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.tandfonline.com/doi/10.1517/14622416.1.4.417?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 11257926 from https://www.tandfonline.com/doi/10.1517/14622416.1.4.417?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1002/jcb.28571
# ERROR:root:Failed to fetch https://doi.org/10.1002/jcb.28571 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 30861201 from https://doi.org/10.1002/jcb.28571
# WARNING:root:Timeout on attempt 1/1 for https://academic.oup.com/mr/article-lookup/doi/10.1080/14397595.2019.1601852
# ERROR:root:Failed to fetch https://academic.oup.com/mr/article-lookup/doi/10.1080/14397595.2019.1601852 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 30924376 from https://academic.oup.com/mr/article-lookup/doi/10.1080/14397595.2019.1601852
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1111/iji.12077
# ERROR:root:Failed to fetch https://doi.org/10.1111/iji.12077 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 23870089 from https://doi.org/10.1111/iji.12077
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.tandfonline.com/doi/10.1080/15513815.2019.1686789?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.tandfonline.com/doi/10.1080/15513815.2019.1686789?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 31738634 from https://www.tandfonline.com/doi/10.1080/15513815.2019.1686789?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1111/ahg.12285
# ERROR:root:Failed to fetch https://doi.org/10.1111/ahg.12285 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 30256383 from https://doi.org/10.1111/ahg.12285
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.ahajournals.org/doi/10.1161/CIRCGEN.118.002365?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.ahajournals.org/doi/10.1161/CIRCGEN.118.002365?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 31017802 from https://www.ahajournals.org/doi/10.1161/CIRCGEN.118.002365?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:No full text links (list or single) found for PMID 30853710
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.tandfonline.com/doi/10.3109/15412555.2015.1021914?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.tandfonline.com/doi/10.3109/15412555.2015.1021914?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 25938291 from https://www.tandfonline.com/doi/10.3109/15412555.2015.1021914?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:Timeout on attempt 1/1 for https://doi.org/10.1038/s41397-019-0085-1
# ERROR:root:Failed to fetch https://doi.org/10.1038/s41397-019-0085-1 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 30971808 from https://doi.org/10.1038/s41397-019-0085-1
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.ahajournals.org/doi/10.1161/CIRCULATIONAHA.123.064734?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.ahajournals.org/doi/10.1161/CIRCULATIONAHA.123.064734?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 37905415 from https://www.ahajournals.org/doi/10.1161/CIRCULATIONAHA.123.064734?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch full content for PMID 20149326 from http://www.clinexprheumatol.org/pubmed/find-pii.asp?pii=20149326
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.ahajournals.org/doi/10.1161/CIRCGEN.117.002020?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.ahajournals.org/doi/10.1161/CIRCGEN.117.002020?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 29453247 from https://www.ahajournals.org/doi/10.1161/CIRCGEN.117.002020?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1111/j.1442-200X.2010.03160.x
# ERROR:root:Failed to fetch https://doi.org/10.1111/j.1442-200X.2010.03160.x after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 20487372 from https://doi.org/10.1111/j.1442-200X.2010.03160.x
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1002/ajmg.a.61593
# ERROR:root:Failed to fetch https://doi.org/10.1002/ajmg.a.61593 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 32293785 from https://doi.org/10.1002/ajmg.a.61593
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1002/jgm.3066
# ERROR:root:Failed to fetch https://doi.org/10.1002/jgm.3066 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 30576025 from https://doi.org/10.1002/jgm.3066
# WARNING:root:No full text links (list or single) found for PMID 22331720
# WARNING:root:Timeout on attempt 1/1 for http://www.geneticsmr.com/articles/4547
# ERROR:root:Failed to fetch http://www.geneticsmr.com/articles/4547 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 26125827 from http://www.geneticsmr.com/articles/4547
# WARNING:root:Timeout on attempt 1/1 for https://dx.doi.org/10.1007/s00246-012-0289-5
# ERROR:root:Failed to fetch https://dx.doi.org/10.1007/s00246-012-0289-5 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 22450355 from https://dx.doi.org/10.1007/s00246-012-0289-5
# WARNING:root:Timeout on attempt 1/1 for https://www.yiigle.com/LinkIn.do?linkin_type=pubmed&issn=0578-1310&year=2004&vol=42&issue=3&fpage=176
# ERROR:root:Failed to fetch https://www.yiigle.com/LinkIn.do?linkin_type=pubmed&issn=0578-1310&year=2004&vol=42&issue=3&fpage=176 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 15144709 from https://www.yiigle.com/LinkIn.do?linkin_type=pubmed&issn=0578-1310&year=2004&vol=42&issue=3&fpage=176
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.ahajournals.org/doi/abs/10.1161/ATVBAHA.123.320188?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.ahajournals.org/doi/abs/10.1161/ATVBAHA.123.320188?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 38357816 from https://www.ahajournals.org/doi/abs/10.1161/ATVBAHA.123.320188?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1111/1756-185X.12968
# ERROR:root:Failed to fetch https://doi.org/10.1111/1756-185X.12968 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 28036156 from https://doi.org/10.1111/1756-185X.12968
# WARNING:root:No full text links (list or single) found for PMID 18260324
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1002/pbc.20715
# ERROR:root:Failed to fetch https://doi.org/10.1002/pbc.20715 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 16358309 from https://doi.org/10.1002/pbc.20715
# WARNING:root:No full text links (list or single) found for PMID 7591865
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/37561683/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/37561683/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 37561683
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/36310304/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/36310304/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 36310304
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1002/ajmg.a.62397
# ERROR:root:Failed to fetch https://doi.org/10.1002/ajmg.a.62397 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 34189822 from https://doi.org/10.1002/ajmg.a.62397
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.tandfonline.com/doi/10.1080/08820139.2021.1877302?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.tandfonline.com/doi/10.1080/08820139.2021.1877302?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 33501869 from https://www.tandfonline.com/doi/10.1080/08820139.2021.1877302?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.tandfonline.com/doi/10.1080/08820139.2018.1529790?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.tandfonline.com/doi/10.1080/08820139.2018.1529790?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 30321073 from https://www.tandfonline.com/doi/10.1080/08820139.2018.1529790?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/23445729/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/23445729/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 23445729
# WARNING:root:No full text links (list or single) found for PMID 19950847
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1002/wsbm.1202
# ERROR:root:Failed to fetch https://doi.org/10.1002/wsbm.1202 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 23293016 from https://doi.org/10.1002/wsbm.1202
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/36430629/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/36430629/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 36430629
# ERROR:root:Failed to fetch full content for PMID 21418786 from http://www.clinexprheumatol.org/pubmed/find-pii.asp?pii=21418786
# WARNING:root:Timeout on attempt 1/1 for https://academic.oup.com/jpids/article-lookup/doi/10.1093/jpids/piad010
# ERROR:root:Failed to fetch https://academic.oup.com/jpids/article-lookup/doi/10.1093/jpids/piad010 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 36786499 from https://academic.oup.com/jpids/article-lookup/doi/10.1093/jpids/piad010
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/36149537/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/36149537/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 36149537
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/30468029/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/30468029/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 30468029
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/28427379/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/28427379/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 28427379
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1111/ped.12983
# ERROR:root:Failed to fetch https://doi.org/10.1111/ped.12983 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 27553890 from https://doi.org/10.1111/ped.12983
# WARNING:root:No full text links (list or single) found for PMID 15954382
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1002/art.42808
# ERROR:root:Failed to fetch https://doi.org/10.1002/art.42808 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 38268504 from https://doi.org/10.1002/art.42808
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1111/apa.17054
# ERROR:root:Failed to fetch https://doi.org/10.1111/apa.17054 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 38066729 from https://doi.org/10.1111/apa.17054
# WARNING:root:No full text links (list or single) found for PMID 31965063
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.tandfonline.com/doi/10.1080/02688697.2018.1559275?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.tandfonline.com/doi/10.1080/02688697.2018.1559275?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 30681383 from https://www.tandfonline.com/doi/10.1080/02688697.2018.1559275?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:No full text links (list or single) found for PMID 18260323
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1111/j.1744-313X.2011.01065.x
# ERROR:root:Failed to fetch https://doi.org/10.1111/j.1744-313X.2011.01065.x after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 22117627 from https://doi.org/10.1111/j.1744-313X.2011.01065.x
# WARNING:root:Timeout on attempt 1/1 for http://www.begellhouse.com/journals/6dbf508d3b17c437,478e880265896a53,1fc0f5a93154e145.html
# ERROR:root:Failed to fetch http://www.begellhouse.com/journals/6dbf508d3b17c437,478e880265896a53,1fc0f5a93154e145.html after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 32421987 from http://www.begellhouse.com/journals/6dbf508d3b17c437,478e880265896a53,1fc0f5a93154e145.html
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/35732822/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/35732822/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 35732822
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/35218979/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/35218979/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 35218979
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/35012285/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/35012285/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 35012285
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/34174887/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/34174887/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 34174887
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.liebertpub.com/doi/10.1089/bfm.2021.0216?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.liebertpub.com/doi/10.1089/bfm.2021.0216?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 34939829 from https://www.liebertpub.com/doi/10.1089/bfm.2021.0216?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.tandfonline.com/doi/10.1080/08820139.2020.1727919?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.tandfonline.com/doi/10.1080/08820139.2020.1727919?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 32079425 from https://www.tandfonline.com/doi/10.1080/08820139.2020.1727919?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:HTTP error 403 on attempt 1/1 for https://onlinelibrary.wiley.com/doi/10.1002/art.21810
# ERROR:root:Failed to fetch https://onlinelibrary.wiley.com/doi/10.1002/art.21810 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 16645964 from https://onlinelibrary.wiley.com/doi/10.1002/art.21810
# ...
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1002/ajmg.a.63409
# ERROR:root:Failed to fetch https://doi.org/10.1002/ajmg.a.63409 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 37753667 from https://doi.org/10.1002/ajmg.a.63409
# WARNING:root:HTTP error 403 on attempt 1/1 for https://journals.sagepub.com/doi/10.1177/00033197221118343?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://journals.sagepub.com/doi/10.1177/00033197221118343?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 36056535 from https://journals.sagepub.com/doi/10.1177/00033197221118343?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/34952936/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/34952936/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 34952936
# WARNING:root:No full text links (list or single) found for PMID 31455486
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1111/pai.13381
# ERROR:root:Failed to fetch https://doi.org/10.1111/pai.13381 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 32989803 from https://doi.org/10.1111/pai.13381
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.tandfonline.com/doi/abs/10.1080/21691401.2019.1645156?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.tandfonline.com/doi/abs/10.1080/21691401.2019.1645156?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 32072832 from https://www.tandfonline.com/doi/abs/10.1080/21691401.2019.1645156?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:Timeout on attempt 1/1 for https://doi.org/10.1038/pr.2017.183
# ERROR:root:Failed to fetch https://doi.org/10.1038/pr.2017.183 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 28753597 from https://doi.org/10.1038/pr.2017.183
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1111/j.1442-200X.2012.03608.x
# ERROR:root:Failed to fetch https://doi.org/10.1111/j.1442-200X.2012.03608.x after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 22414298 from https://doi.org/10.1111/j.1442-200X.2012.03608.x
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.tandfonline.com/doi/10.1080/1744666X.2024.2401105?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.tandfonline.com/doi/10.1080/1744666X.2024.2401105?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 39230194 from https://www.tandfonline.com/doi/10.1080/1744666X.2024.2401105?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/39359734/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/39359734/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 39359734
# WARNING:root:HTTP error 403 on attempt 1/1 for https://journals.sagepub.com/doi/10.1177/21501351231205570?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://journals.sagepub.com/doi/10.1177/21501351231205570?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 37981829 from https://journals.sagepub.com/doi/10.1177/21501351231205570?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:Timeout on attempt 1/1 for https://doi.org/10.1159/000531296
# ERROR:root:Failed to fetch https://doi.org/10.1159/000531296 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 38194943 from https://doi.org/10.1159/000531296
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.tandfonline.com/doi/abs/10.1080/16078454.2023.2277502?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.tandfonline.com/doi/abs/10.1080/16078454.2023.2277502?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 37933872 from https://www.tandfonline.com/doi/abs/10.1080/16078454.2023.2277502?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.tandfonline.com/doi/10.1080/1744666X.2023.2238122?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.tandfonline.com/doi/10.1080/1744666X.2023.2238122?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 37458237 from https://www.tandfonline.com/doi/10.1080/1744666X.2023.2238122?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/31867296/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/31867296/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 31867296
# WARNING:root:No full text links (list or single) found for PMID 25518415
# WARNING:root:No full text links (list or single) found for PMID 17294875
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.tandfonline.com/doi/10.1080/15513815.2024.2414175?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.tandfonline.com/doi/10.1080/15513815.2024.2414175?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 39485066 from https://www.tandfonline.com/doi/10.1080/15513815.2024.2414175?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:Timeout on attempt 1/1 for https://academic.oup.com/jid/article-lookup/doi/10.1093/infdis/jiae480
# ERROR:root:Failed to fetch https://academic.oup.com/jid/article-lookup/doi/10.1093/infdis/jiae480 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 39328079 from https://academic.oup.com/jid/article-lookup/doi/10.1093/infdis/jiae480
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1111/sji.13373
# ERROR:root:Failed to fetch https://doi.org/10.1111/sji.13373 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 38757311 from https://doi.org/10.1111/sji.13373
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.liebertpub.com/doi/10.1089/vim.2023.0074?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.liebertpub.com/doi/10.1089/vim.2023.0074?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 38271561 from https://www.liebertpub.com/doi/10.1089/vim.2023.0074?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:Timeout on attempt 1/1 for https://academic.oup.com/glycob/article-lookup/doi/10.1093/glycob/cwad096
# ERROR:root:Failed to fetch https://academic.oup.com/glycob/article-lookup/doi/10.1093/glycob/cwad096 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 38039077 from https://academic.oup.com/glycob/article-lookup/doi/10.1093/glycob/cwad096
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1002/jgm.3514
# ERROR:root:Failed to fetch https://doi.org/10.1002/jgm.3514 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 37097087 from https://doi.org/10.1002/jgm.3514
# WARNING:root:HTTP error 403 on attempt 1/1 for https://onlinelibrary.wiley.com/doi/10.1111/febs.16776
# ERROR:root:Failed to fetch https://onlinelibrary.wiley.com/doi/10.1111/febs.16776 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 36974504 from https://onlinelibrary.wiley.com/doi/10.1111/febs.16776
# WARNING:root:Timeout on attempt 1/1 for https://dx.doi.org/10.1007/s10067-023-06636-2
# ERROR:root:Failed to fetch https://dx.doi.org/10.1007/s10067-023-06636-2 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 37394620 from https://dx.doi.org/10.1007/s10067-023-06636-2
# WARNING:root:Timeout on attempt 1/1 for https://linkinghub.elsevier.com/retrieve/pii/S0171-2985(22)00111-5
# ERROR:root:Failed to fetch https://linkinghub.elsevier.com/retrieve/pii/S0171-2985(22)00111-5 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 36240611 from https://linkinghub.elsevier.com/retrieve/pii/S0171-2985(22)00111-5
# WARNING:root:HTTP error 403 on attempt 1/1 for https://econtent.hogrefe.com/doi/10.1024/0040-5930.58.2.87?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://econtent.hogrefe.com/doi/10.1024/0040-5930.58.2.87?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 11234456 from https://econtent.hogrefe.com/doi/10.1024/0040-5930.58.2.87?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:Timeout on attempt 1/1 for https://doi.org/10.1007/978-1-4939-2687-9_13
# ERROR:root:Failed to fetch https://doi.org/10.1007/978-1-4939-2687-9_13 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 25981475 from https://doi.org/10.1007/978-1-4939-2687-9_13
# WARNING:root:No full text links (list or single) found for PMID 9432736
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.liebertpub.com/doi/10.1089/jir.2025.0029?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.liebertpub.com/doi/10.1089/jir.2025.0029?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 40340576 from https://www.liebertpub.com/doi/10.1089/jir.2025.0029?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:HTTP error 403 on attempt 1/1 for https://doi.org/10.1111/1756-185X.70191
# ERROR:root:Failed to fetch https://doi.org/10.1111/1756-185X.70191 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 40143619 from https://doi.org/10.1111/1756-185X.70191
# WARNING:root:Request error on attempt 1/1 for https://www.cambridge.org/core/product/identifier/S1047951124026854/type/journal_article: HTTPSConnectionPool(host='www.cambridge.org', port=443): Read timed out.
# ERROR:root:Failed to fetch https://www.cambridge.org/core/product/identifier/S1047951124026854/type/journal_article after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 39438774 from https://www.cambridge.org/core/product/identifier/S1047951124026854/type/journal_article
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.liebertpub.com/doi/10.1089/gtmb.2024.0035?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.liebertpub.com/doi/10.1089/gtmb.2024.0035?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 39185556 from https://www.liebertpub.com/doi/10.1089/gtmb.2024.0035?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:HTTP error 403 on attempt 1/1 for http://www.scielo.cl/scielo.php?script=sci_arttext&pid=S2452-60532024005000310&lng=en&nrm=iso&tlng=en
# ERROR:root:Failed to fetch http://www.scielo.cl/scielo.php?script=sci_arttext&pid=S2452-60532024005000310&lng=en&nrm=iso&tlng=en after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 38801365 from http://www.scielo.cl/scielo.php?script=sci_arttext&pid=S2452-60532024005000310&lng=en&nrm=iso&tlng=en
# WARNING:root:Timeout on attempt 1/1 for https://academic.oup.com/cei/article-lookup/doi/10.1093/cei/uxae062
# ERROR:root:Failed to fetch https://academic.oup.com/cei/article-lookup/doi/10.1093/cei/uxae062 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 39028583 from https://academic.oup.com/cei/article-lookup/doi/10.1093/cei/uxae062
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.nejm.org/doi/10.1056/NEJMc2306485?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.nejm.org/doi/10.1056/NEJMc2306485?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 37467513 from https://www.nejm.org/doi/10.1056/NEJMc2306485?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.nejm.org/doi/10.1056/NEJMc2306485?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.nejm.org/doi/10.1056/NEJMc2306485?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 37467512 from https://www.nejm.org/doi/10.1056/NEJMc2306485?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:Timeout on attempt 1/1 for https://academic.oup.com/tropej/article-lookup/doi/10.1093/tropej/fmad022
# ERROR:root:Failed to fetch https://academic.oup.com/tropej/article-lookup/doi/10.1093/tropej/fmad022 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 37608506 from https://academic.oup.com/tropej/article-lookup/doi/10.1093/tropej/fmad022
# WARNING:root:HTTP error 403 on attempt 1/1 for https://www.liebertpub.com/doi/10.1089/ped.2023.0045?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# ERROR:root:Failed to fetch https://www.liebertpub.com/doi/10.1089/ped.2023.0045?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 37466470 from https://www.liebertpub.com/doi/10.1089/ped.2023.0045?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub  0pubmed
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/34859644/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/34859644/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 34859644
# WARNING:root:Timeout on attempt 1/1 for https://pubmed.ncbi.nlm.nih.gov/34784874/
# ERROR:root:Failed to fetch https://pubmed.ncbi.nlm.nih.gov/34784874/ after 1 retries.
# ERROR:root:Failed to fetch PubMed page for PMID 34784874
# WARNING:root:No full text links (list or single) found for PMID 33599408
# WARNING:root:No full text links (list or single) found for PMID 25518402
# WARNING:root:Timeout on attempt 1/1 for https://www.yiigle.com/LinkIn.do?linkin_type=pubmed&DOI=10.3760/cma.j.issn.0578-1310.2017.07.012
# ERROR:root:Failed to fetch https://www.yiigle.com/LinkIn.do?linkin_type=pubmed&DOI=10.3760/cma.j.issn.0578-1310.2017.07.012 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 28728263 from https://www.yiigle.com/LinkIn.do?linkin_type=pubmed&DOI=10.3760/cma.j.issn.0578-1310.2017.07.012
# WARNING:root:No full text links (list or single) found for PMID 17972613
# WARNING:root:No full text links (list or single) found for PMID 1504229
# WARNING:root:Timeout on attempt 1/1 for https://dx.doi.org/10.1007/s10157-013-0805-9
# ERROR:root:Failed to fetch https://dx.doi.org/10.1007/s10157-013-0805-9 after 1 retries.
# ERROR:root:Failed to fetch full content for PMID 23615782 from https://dx.doi.org/10.1007/s10157-013-0805-9
# Saved results. Total entries in content_dict.pkl.gz: 923
#
# Fetching complete. Total successfully processed new PMIDs: 711. Total entries in content_dict.pkl.gz: 923
